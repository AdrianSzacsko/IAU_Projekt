# %%
#import ax as ax
from copy import deepcopy

import numpy as np
import math as math
import scipy as sc
import pandas as pd
import matplotlib as mt
import matplotlib.pyplot as plt
import seaborn as sns
#import sklearn as sk
from sklearn.impute import SimpleImputer, KNNImputer

# %% [markdown]
# # Fáza 1 - prieskumná analýza
#
# Pomer práce 50% - 50%
#
# Autori: Jakub Smorada, Adrian Szacsko

# %% [markdown]
# ## 1. Základný opis dát spolu s ich charakteristikami (5 bodov)
#
# Z načítaného datasetu sme odstránili indexy, pretože nám ich knižnica pandas pridá sama.

# %%
from matplotlib import pyplot
sns.set_theme(style="dark", palette="rocket")
dataset = pd.read_csv("042/labor.csv", delimiter="\t")
dataset.drop(dataset.columns[0], axis=1, inplace=True)
dataset
# Out:
#                      name  hematokrit smoker  leukocyty relationship  \
# 0         Courtney Sparks     5.10789     no    3.67594      married
# 1              David Cook     6.06717     no    6.61722      divoced
# 2              Diane Dunn         NaN     no    8.84155      married
# 3           Debra Cameron     8.52161      Y    8.76540      married
# 4      Vincent Mccullough     4.35962     no    6.61320      divoced
# ...                   ...         ...    ...        ...          ...
# 10034     Kenneth Sanchez     4.67432      N    5.22478      married
# 10035   Jennifer Franklin     5.38144      Y    6.77403      widowed
# 10036      Valerie Carter     3.16568      Y    6.30583      married
# 10037        Julie Newman     4.80303      Y    6.78358      widowed
# 10038   Jennifer Mcintyre     7.04535      Y    5.89654       single
#
#                ssn      alt     weight  erytrocyty       alp       ast  \
# 0      211-15-5030  1.36076   65.50748     7.92270  80.65839  40.27331
# 1      134-25-6459  1.10335   80.56053     7.13748  95.49950  51.14865
# 2      410-38-6674  2.32670  165.53795     8.77005  88.36972  56.40210
# 3      327-02-6401  3.08378   56.12232     9.11128  57.21363  57.61393
# 4      469-50-8029  5.08135   93.52107     9.68805  82.12788  75.41991
# ...            ...      ...        ...         ...       ...       ...
# 10034  035-07-2574  0.75385    4.79395     7.40597  80.98445  42.89142
# 10035  369-05-1763  0.68170   72.43763     7.38835  88.27656  55.07674
# 10036  546-10-0083  0.49297   26.26844     6.22727  49.46443  56.32268
# 10037  556-01-2815  1.92676   57.92751     8.64693  44.97615  53.85140
# 10038  078-25-7938  0.33727   67.46315     4.40982  59.33639  60.44024
#
#           er-cv    etytr  hemoglobin  trombocyty  indicator    hbver
# 0      46.67907  6.93084     7.07385     2.43339        0.0  6.73439
# 1      21.09764  6.17378     6.30636     3.16922        0.0  6.69188
# 2      28.48174  7.23321     6.44218     6.13313        0.0  6.33770
# 3      67.05110  7.25101     7.74219     5.54453        0.0  6.08754
# 4      53.04260  6.18335     5.69975     5.34519        0.0  6.34100
# ...         ...      ...         ...         ...        ...      ...
# 10034  47.93544  5.69357     6.46889     4.59180        0.0  6.23398
# 10035  43.86325  5.33810     6.04664     8.02259        1.0  7.56910
# 10036  59.28561  8.32349     4.43833     9.62061        1.0  7.53199
# 10037  56.17723  7.25014     8.14832     6.77935        1.0  4.97849
# 10038  72.19421  6.32660     7.43364     7.86389        1.0  6.90337
#
# [10039 rows x 17 columns]

# %% [markdown]
# ### Počet záznamov a počet atribútov:
#
# Pomocou funkcie len() sme sa dozvedeli koľko máme záznamov a atribútov. Záznamov je 10039 a atribútov je 17.

# %%
profiles = len(dataset.index)
attributes = len(dataset.columns)
data = [[profiles], [attributes]]
sum_of_dataset = pd.DataFrame(data, columns = ['Number'], index = ['Profiles','Attributes'])
sum_of_dataset.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcd9e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcd9e_level0_row0" class="row_heading level0 row0" >Profiles</th>
#       <td id="T_fcd9e_row0_col0" class="data row0 col0" >10039</td>
#     </tr>
#     <tr>
#       <th id="T_fcd9e_level0_row1" class="row_heading level0 row1" >Attributes</th>
#       <td id="T_fcd9e_row1_col0" class="data row1 col0" >17</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Typy dát:
# Jednotlivé typy dát sú viditeľné v nasledujúcej tabuľke.

# %%
info = pd.DataFrame(dataset.dtypes)
info = info.set_axis(['Dtype'], axis=1, inplace=False)
info.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a371d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a371d_level0_row0" class="row_heading level0 row0" >name</th>
#       <td id="T_a371d_row0_col0" class="data row0 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row1" class="row_heading level0 row1" >hematokrit</th>
#       <td id="T_a371d_row1_col0" class="data row1 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row2" class="row_heading level0 row2" >smoker</th>
#       <td id="T_a371d_row2_col0" class="data row2 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row3" class="row_heading level0 row3" >leukocyty</th>
#       <td id="T_a371d_row3_col0" class="data row3 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row4" class="row_heading level0 row4" >relationship</th>
#       <td id="T_a371d_row4_col0" class="data row4 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row5" class="row_heading level0 row5" >ssn</th>
#       <td id="T_a371d_row5_col0" class="data row5 col0" >object</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row6" class="row_heading level0 row6" >alt</th>
#       <td id="T_a371d_row6_col0" class="data row6 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row7" class="row_heading level0 row7" >weight</th>
#       <td id="T_a371d_row7_col0" class="data row7 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row8" class="row_heading level0 row8" >erytrocyty</th>
#       <td id="T_a371d_row8_col0" class="data row8 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row9" class="row_heading level0 row9" >alp</th>
#       <td id="T_a371d_row9_col0" class="data row9 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row10" class="row_heading level0 row10" >ast</th>
#       <td id="T_a371d_row10_col0" class="data row10 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row11" class="row_heading level0 row11" >er-cv</th>
#       <td id="T_a371d_row11_col0" class="data row11 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row12" class="row_heading level0 row12" >etytr</th>
#       <td id="T_a371d_row12_col0" class="data row12 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row13" class="row_heading level0 row13" >hemoglobin</th>
#       <td id="T_a371d_row13_col0" class="data row13 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row14" class="row_heading level0 row14" >trombocyty</th>
#       <td id="T_a371d_row14_col0" class="data row14 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row15" class="row_heading level0 row15" >indicator</th>
#       <td id="T_a371d_row15_col0" class="data row15 col0" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_a371d_level0_row16" class="row_heading level0 row16" >hbver</th>
#       <td id="T_a371d_row16_col0" class="data row16 col0" >float64</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Distribúcia významných atribútov:
#
# Pomocou knižnice pandas sme vytvorili rôzne histogramy pre niekoľko významných atribútov, napr. **hematokrit, leukocyty, alt, weight, erytrocyty, alp,
# ast, er-cv, etytr, hemoglobin, trombocyty, indicator, hbver**

# %%
# dataset.head()
fig = dataset.hist(bins=8, figsize=[25, 25], xlabelsize=14, ylabelsize=14)
[x.title.set_size(28) for x in fig.ravel()]
fig
# Out:
# array([[<AxesSubplot:title={'center':'hematokrit'}>,
#         <AxesSubplot:title={'center':'leukocyty'}>,
#         <AxesSubplot:title={'center':'alt'}>,
#         <AxesSubplot:title={'center':'weight'}>],
#        [<AxesSubplot:title={'center':'erytrocyty'}>,
#         <AxesSubplot:title={'center':'alp'}>,
#         <AxesSubplot:title={'center':'ast'}>,
#         <AxesSubplot:title={'center':'er-cv'}>],
#        [<AxesSubplot:title={'center':'etytr'}>,
#         <AxesSubplot:title={'center':'hemoglobin'}>,
#         <AxesSubplot:title={'center':'trombocyty'}>,
#         <AxesSubplot:title={'center':'indicator'}>],
#        [<AxesSubplot:title={'center':'hbver'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Základné deskriptívne štatistiky
#
# K základný deskriptívnym štatistikám patria: **medián, modus, priemer, smerodajná odchýlka, minimálna
# a maximálna hodnota, variancia, atď.**
#
# *Vypočítanie modusu nemá význam, pretože jednotlivé záznamy sú unikátne (nevyskytujú sa viackrát).*

# %%
desc_stat_table = dataset.select_dtypes(include=[np.float64])
desc_stat = dataset.describe()
desc_stat.loc['median'] = desc_stat_table.median()
desc_stat.loc['variance'] = desc_stat_table.var()
# modus nie je mozne urobit, su unikátne
desc_stat.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_14bf7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >hematokrit</th>
#       <th class="col_heading level0 col1" >leukocyty</th>
#       <th class="col_heading level0 col2" >alt</th>
#       <th class="col_heading level0 col3" >weight</th>
#       <th class="col_heading level0 col4" >erytrocyty</th>
#       <th class="col_heading level0 col5" >alp</th>
#       <th class="col_heading level0 col6" >ast</th>
#       <th class="col_heading level0 col7" >er-cv</th>
#       <th class="col_heading level0 col8" >etytr</th>
#       <th class="col_heading level0 col9" >hemoglobin</th>
#       <th class="col_heading level0 col10" >trombocyty</th>
#       <th class="col_heading level0 col11" >indicator</th>
#       <th class="col_heading level0 col12" >hbver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14bf7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_14bf7_row0_col0" class="data row0 col0" >10008.000000</td>
#       <td id="T_14bf7_row0_col1" class="data row0 col1" >10009.000000</td>
#       <td id="T_14bf7_row0_col2" class="data row0 col2" >10009.000000</td>
#       <td id="T_14bf7_row0_col3" class="data row0 col3" >10039.000000</td>
#       <td id="T_14bf7_row0_col4" class="data row0 col4" >10009.000000</td>
#       <td id="T_14bf7_row0_col5" class="data row0 col5" >10008.000000</td>
#       <td id="T_14bf7_row0_col6" class="data row0 col6" >10009.000000</td>
#       <td id="T_14bf7_row0_col7" class="data row0 col7" >10009.000000</td>
#       <td id="T_14bf7_row0_col8" class="data row0 col8" >10008.000000</td>
#       <td id="T_14bf7_row0_col9" class="data row0 col9" >10009.000000</td>
#       <td id="T_14bf7_row0_col10" class="data row0 col10" >10009.000000</td>
#       <td id="T_14bf7_row0_col11" class="data row0 col11" >10039.000000</td>
#       <td id="T_14bf7_row0_col12" class="data row0 col12" >10009.000000</td>
#     </tr>
#     <tr>
#       <th id="T_14bf7_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_14bf7_row1_col0" class="data row1 col0" >6.453032</td>
#       <td id="T_14bf7_row1_col1" class="data row1 col1" >6.450274</td>
#       <td id="T_14bf7_row1_col2" class="data row1 col2" >1.306090</td>
#       <td id="T_14bf7_row1_col3" class="data row1 col3" >69.805192</td>
#       <td id="T_14bf7_row1_col4" class="data row1 col4" >6.898802</td>
#       <td id="T_14bf7_row1_col5" class="data row1 col5" >71.949719</td>
#       <td id="T_14bf7_row1_col6" class="data row1 col6" >52.343359</td>
#       <td id="T_14bf7_row1_col7" class="data row1 col7" >49.060376</td>
#       <td id="T_14bf7_row1_col8" class="data row1 col8" >6.476717</td>
#       <td id="T_14bf7_row1_col9" class="data row1 col9" >6.464414</td>
#       <td id="T_14bf7_row1_col10" class="data row1 col10" >6.828460</td>
#       <td id="T_14bf7_row1_col11" class="data row1 col11" >0.642295</td>
#       <td id="T_14bf7_row1_col12" class="data row1 col12" >6.475601</td>
#     </tr>
#     <tr>
#       <th id="T_14bf7_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_14bf7_row2_col0" class="data row2 col0" >1.665991</td>
#       <td id="T_14bf7_row2_col1" class="data row2 col1" >1.700428</td>
#       <td id="T_14bf7_row2_col2" class="data row2 col2" >2.080683</td>
#       <td id="T_14bf7_row2_col3" class="data row2 col3" >35.581044</td>
#       <td id="T_14bf7_row2_col4" class="data row2 col4" >1.605785</td>
#       <td id="T_14bf7_row2_col5" class="data row2 col5" >18.109229</td>
#       <td id="T_14bf7_row2_col6" class="data row2 col6" >11.880597</td>
#       <td id="T_14bf7_row2_col7" class="data row2 col7" >13.084279</td>
#       <td id="T_14bf7_row2_col8" class="data row2 col8" >0.994156</td>
#       <td id="T_14bf7_row2_col9" class="data row2 col9" >1.006072</td>
#       <td id="T_14bf7_row2_col10" class="data row2 col10" >1.734330</td>
#       <td id="T_14bf7_row2_col11" class="data row2 col11" >0.479349</td>
#       <td id="T_14bf7_row2_col12" class="data row2 col12" >1.004527</td>
#     </tr>
#     <tr>
#       <th id="T_14bf7_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_14bf7_row3_col0" class="data row3 col0" >0.683890</td>
#       <td id="T_14bf7_row3_col1" class="data row3 col1" >0.979140</td>
#       <td id="T_14bf7_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_14bf7_row3_col3" class="data row3 col3" >-59.892790</td>
#       <td id="T_14bf7_row3_col4" class="data row3 col4" >1.811270</td>
#       <td id="T_14bf7_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_14bf7_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_14bf7_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_14bf7_row3_col8" class="data row3 col8" >2.678710</td>
#       <td id="T_14bf7_row3_col9" class="data row3 col9" >3.054200</td>
#       <td id="T_14bf7_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_14bf7_row3_col11" class="data row3 col11" >0.000000</td>
#       <td id="T_14bf7_row3_col12" class="data row3 col12" >2.738210</td>
#     </tr>
#     <tr>
#       <th id="T_14bf7_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_14bf7_row4_col0" class="data row4 col0" >5.197180</td>
#       <td id="T_14bf7_row4_col1" class="data row4 col1" >5.177990</td>
#       <td id="T_14bf7_row4_col2" class="data row4 col2" >0.521560</td>
#       <td id="T_14bf7_row4_col3" class="data row4 col3" >46.183730</td>
#       <td id="T_14bf7_row4_col4" class="data row4 col4" >5.748830</td>
#       <td id="T_14bf7_row4_col5" class="data row4 col5" >63.818647</td>
#       <td id="T_14bf7_row4_col6" class="data row4 col6" >44.490180</td>
#       <td id="T_14bf7_row4_col7" class="data row4 col7" >40.393810</td>
#       <td id="T_14bf7_row4_col8" class="data row4 col8" >5.802672</td>
#       <td id="T_14bf7_row4_col9" class="data row4 col9" >5.786020</td>
#       <td id="T_14bf7_row4_col10" class="data row4 col10" >5.665190</td>
#       <td id="T_14bf7_row4_col11" class="data row4 col11" >0.000000</td>
#       <td id="T_14bf7_row4_col12" class="data row4 col12" >5.806840</td>
#     </tr>
#     <tr>
#       <th id="T_14bf7_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_14bf7_row5_col0" class="data row5 col0" >6.227605</td>
#       <td id="T_14bf7_row5_col1" class="data row5 col1" >6.352150</td>
#       <td id="T_14bf7_row5_col2" class="data row5 col2" >0.773820</td>
#       <td id="T_14bf7_row5_col3" class="data row5 col3" >70.018130</td>
#       <td id="T_14bf7_row5_col4" class="data row5 col4" >7.036180</td>
#       <td id="T_14bf7_row5_col5" class="data row5 col5" >78.203065</td>
#       <td id="T_14bf7_row5_col6" class="data row5 col6" >52.376590</td>
#       <td id="T_14bf7_row5_col7" class="data row5 col7" >48.923340</td>
#       <td id="T_14bf7_row5_col8" class="data row5 col8" >6.480035</td>
#       <td id="T_14bf7_row5_col9" class="data row5 col9" >6.476210</td>
#       <td id="T_14bf7_row5_col10" class="data row5 col10" >7.002890</td>
#       <td id="T_14bf7_row5_col11" class="data row5 col11" >1.000000</td>
#       <td id="T_14bf7_row5_col12" class="data row5 col12" >6.478430</td>
#     </tr>
#     <tr>
#       <th id="T_14bf7_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_14bf7_row6_col0" class="data row6 col0" >7.669982</td>
#       <td id="T_14bf7_row6_col1" class="data row6 col1" >7.693890</td>
#       <td id="T_14bf7_row6_col2" class="data row6 col2" >1.344220</td>
#       <td id="T_14bf7_row6_col3" class="data row6 col3" >93.175640</td>
#       <td id="T_14bf7_row6_col4" class="data row6 col4" >8.052080</td>
#       <td id="T_14bf7_row6_col5" class="data row6 col5" >84.986902</td>
#       <td id="T_14bf7_row6_col6" class="data row6 col6" >60.275100</td>
#       <td id="T_14bf7_row6_col7" class="data row6 col7" >57.766910</td>
#       <td id="T_14bf7_row6_col8" class="data row6 col8" >7.147997</td>
#       <td id="T_14bf7_row6_col9" class="data row6 col9" >7.140870</td>
#       <td id="T_14bf7_row6_col10" class="data row6 col10" >8.078720</td>
#       <td id="T_14bf7_row6_

# %% [markdown]
# Pre nami zvolené atribúty sme vykreslili ich distribúcie ako aj opísali ich základné deskriptívne štatistiky.

# %% [markdown]
# #### Hematokrit

# %%
sns.histplot(data=dataset["hematokrit"], kde=True)
desc_stat["hematokrit"]
# Out:
# count       10008.000000
# mean            6.453032
# std             1.665991
# min             0.683890
# 25%             5.197180
# 50%             6.227605
# 75%             7.669982
# max            13.633550
# median          6.227605
# variance        2.775527
# Name: hematokrit, dtype: float64

# %% [markdown]
# ### Leukocyty

# %%
sns.histplot(data=dataset["leukocyty"], kde=True)
desc_stat["leukocyty"]
# Out:
# count       10009.000000
# mean            6.450274
# std             1.700428
# min             0.979140
# 25%             5.177990
# 50%             6.352150
# 75%             7.693890
# max            12.694630
# median          6.352150
# variance        2.891457
# Name: leukocyty, dtype: float64

# %% [markdown]
# ### Alt

# %%
sns.histplot(data=dataset["alt"], kde=True)
desc_stat["alt"]
# Out:
# count       10009.000000
# mean            1.306090
# std             2.080683
# min             0.000000
# 25%             0.521560
# 50%             0.773820
# 75%             1.344220
# max           100.000000
# median          0.773820
# variance        4.329243
# Name: alt, dtype: float64

# %% [markdown]
# ### Alp

# %%
sns.histplot(data=dataset["alp"], kde=True)
desc_stat["alp"]
# Out:
# count       10008.000000
# mean           71.949719
# std            18.109229
# min             0.000000
# 25%            63.818647
# 50%            78.203065
# 75%            84.986902
# max           100.000000
# median         78.203065
# variance      327.944181
# Name: alp, dtype: float64

# %% [markdown]
# ### Trombocyty

# %%
sns.histplot(data=dataset["trombocyty"], kde=True)
desc_stat["trombocyty"]
# Out:
# count       10009.000000
# mean            6.828460
# std             1.734330
# min             0.000000
# 25%             5.665190
# 50%             7.002890
# 75%             8.078720
# max            12.595220
# median          7.002890
# variance        3.007899
# Name: trombocyty, dtype: float64

# %% [markdown]
# ##  2. Párová analýza dát
#
# V tejto sekcii sme preskúmali koreláciu medzi jednotlivými atribútami pomocou funkcie matshow() z knižnice matplotlib.
# Ako je možné vidieť, najvyššia pozitívna korelácia je medzi atribútom **'indicator'** a atribútom **'trombocyty'**.
# Druhá najvyššia pozitívna korelácia je medzi atribútom **'etrocyty'** a atribútom **'alt'**.
# Najvyššia negatívna korelácia je medzi atribútom **'erytrocyty'** a atribútom **'hematokrit'**.

# %%
correllation = dataset.corr()
mt.pyplot.matshow(correllation)
correllation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7eb30_row0_col0, #T_7eb30_row1_col1, #T_7eb30_row2_col2, #T_7eb30_row3_col3, #T_7eb30_row4_col4, #T_7eb30_row5_col5, #T_7eb30_row6_col6, #T_7eb30_row7_col7, #T_7eb30_row8_col8, #T_7eb30_row9_col9, #T_7eb30_row10_col10, #T_7eb30_row11_col11, #T_7eb30_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col1, #T_7eb30_row0_col4, #T_7eb30_row1_col3, #T_7eb30_row1_col12, #T_7eb30_row4_col0, #T_7eb30_row4_col10, #T_7eb30_row4_col11, #T_7eb30_row5_col7, #T_7eb30_row5_col9, #T_7eb30_row6_col7, #T_7eb30_row6_col8, #T_7eb30_row7_col6, #T_7eb30_row8_col6, #T_7eb30_row9_col5, #T_7eb30_row10_col2, #T_7eb30_row10_col8, #T_7eb30_row11_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col3, #T_7eb30_row2_col6, #T_7eb30_row2_col12, #T_7eb30_row7_col8, #T_7eb30_row8_col7, #T_7eb30_row10_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col5, #T_7eb30_row2_col1, #T_7eb30_row6_col2, #T_7eb30_row7_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col6, #T_7eb30_row1_col7, #T_7eb30_row2_col3, #T_7eb30_row2_col7, #T_7eb30_row11_col6, #T_7eb30_row12_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col7, #T_7eb30_row2_col8, #T_7eb30_row3_col7, #T_7eb30_row3_col8, #T_7eb30_row4_col3, #T_7eb30_row4_col6, #T_7eb30_row4_col7, #T_7eb30_row4_col8, #T_7eb30_row4_col12, #T_7eb30_row7_col3, #T_7eb30_row9_col6, #T_7eb30_row9_col7, #T_7eb30_row12_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col8, #T_7eb30_row1_col8, #T_7eb30_row5_col6, #T_7eb30_row5_col8, #T_7eb30_row9_col3, #T_7eb30_row9_col8, #T_7eb30_row10_col3, #T_7eb30_row11_col3, #T_7eb30_row11_col7, #T_7eb30_row12_col7, #T_7eb30_row12_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col9 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col10 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7eb30_row0_col11, #T_7eb30_row3_col11, #T_7eb30_row12_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_7eb30_row0_col12, #T_7eb30_row6_col12, #T_7eb30_row8_col1, #T_7eb30_row9_col1, #T_7eb30_row11_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7eb30_row1_col0, #T_7eb30_row10_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7eb30_row1_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7eb30_row1_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_7eb30_row1_col5, #T_7eb30_row1_col9, #T_7eb30_row2_col5, #T_7eb30_row4_col5, #T_7eb30_row10_col5, #T_7eb30_row12_col2, #T_7eb30_row12_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_7eb30_row1_col6, #T_7eb30_row3_col1, #T_7eb30_row5_col3, #T_7eb30_row5_col12, #T_7eb30_row8_col3, #T_7eb30_row10_col6, #T_7eb30_row10_col12, #T_7eb30_row12_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_7eb30_row1_col10 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_7eb30_row1_col11, #T_7eb30_row7_col11, #T_7eb30_row8_col10, #T_7eb30_row12_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_7eb30_row2_col0, #T_7eb30_row3_col5, #T_7eb30_row6_col9, #T_7eb30_row7_col9, #T_7eb30_row11_col5, #T_7eb30_row11_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7eb30_row2_col4 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_7eb30_row2_col9, #T_7eb30_row3_col9, #T_7eb30_row6_col5, #T_7eb30_row8_col5, #T_7eb30_row8_col9, #T_7eb30_row10_col1, #T_7eb30_row10_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_7eb30_row2_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_7eb30_row2_col11, #T_7eb30_row12_col5 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_7eb30_row3_col0, #T_7eb30_row6_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7eb30_row3_col2, #T_7eb30_row4_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_7eb30_row3_col4, #T_7eb30_row5_col4, #T_7eb30_row6_col4, #T_7eb30_row7_col0, #T_7eb30_row7_col4, #T_7eb30_row8_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_7eb30_row3_col6, #T_7eb30_row3_col12, #T_7eb30_row7_col1, #T_7eb30_row7_col12, #T_7eb30_row8_col12, #T_7eb30_row9_col12 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7eb30_row3_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_7eb30_row4_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7eb30_row4_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_7eb30_row5_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_7eb30_row5_col1, #T_7eb30_row6_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_7eb30_row5_col2, #T_7eb30_row9_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7eb30_row5_col10, #T_7eb30_row6_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_7eb30_row5_col11, #T_7eb30_row7_col10, #T_7eb30_row9_col10, #T_7eb30_row9_col11 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_7eb30_row6_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_7eb30_row6_col11 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_7eb30_row7_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7eb30_row8_col0, #T_7eb30_row11_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_7eb30_row8_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_7eb30_row8_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7eb30_row9_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_7eb30_row9_col4, #T_7eb30_row12_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_7eb30_row10_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_7eb30_row10_col11 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_7eb30_row11_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_7eb30_row11_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_7eb30_row11_col10 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_7eb30_row11_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_7eb30_row12_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# </style>
# <table id="T_7eb30_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >hematokrit</th>
#       <th class="col_heading level0 col1" >leukocyty</th>
#       <th class="col_heading level0 col2" >alt</th>
#       <th class="col_heading level0 col3" >weight</th>
#       <th class="col_heading level0 col4" >erytrocyty</th>
#       <th class="col_heading level0 col5" >alp</th>
#       <th class="col_heading level0 col6" >ast</th>
#       <th class="col_heading level0 col7" >er-cv</th>
#       <th class="col_heading level0 col8" >etytr</th>
#       <th class="col_heading level0 col9" >hemoglobin</th>
#       <th class="col_heading level0 col10" >trombocyty</th>
#       <th class="col_heading level0 col11" >indicator</th>
#       <th class="col_heading level0 col12" >hbver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eb30_level0_row0" class="row_heading level0 row0" >hematokrit</th>
#       <td id="T_7eb30_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7eb30_row0_col1" class="data row0 col1" >-0.035522</td>
#       <td id="T_7eb30_row0_col2" class="data row0 col2" >-0.189589</td>
#       <td id="T_7eb30_row0_col3" class="data row0 col3" >-0.001973</td>
#       <td id="T_7eb30_row0_col4" class="data row0 col4" >-0.465486</td>
#       <td id="T_7eb30_row0_col5" class="data row0 col5" >0.016232</td>
#       <td id="T_7eb30_row0_col6" class="data row0 col6" >-0.005173</td>
#       <td id="T_7eb30_row0_col7" class="data row0 col7" >0.005333</td>
#       <td id="T_7eb30_row0_col8" class="data row0 col8" >0.002552</td>
#       <td id="T_7eb30_row0_col9" class="data row0 col9" >-0.015807</td>
#       <td id="T_7eb30_row0_col10" class="data row0 col10" >-0.035439</td>
#       <td id="T_7eb30_row0_col11" class="data row0 col11" >-0.000303</td>
#       <td id="T_7eb30_row0_col12" class="data row0 col12" >0.010663</td>
#     </tr>
#     <tr>
#       <th id="T_7eb30_level0_row1" class="row_heading level0 row1"

# %% [markdown]
# ### Závislosti medzi dvojicami atribútov:

# %% [markdown]
# #### Alt a Erytrocyty

# %% [markdown]
# Z korelácie vieme vyčítať, že atribút **'alt'** a atribút **'erytrocyty'** majú súvislosť **0.56**, čo znamená,
# že môžeme skúsiť vytvoriť graf, aby sme sa dozvedeli viac.

# %%
sns.scatterplot(data=dataset, x='alt', y='erytrocyty', )
# .set(xscale="log", yscale="log")
# Out:
# <AxesSubplot:xlabel='alt', ylabel='erytrocyty'>

# %% [markdown]
# Z grafu sme sa dozvedeli, že čím väčšia je hodnota **'alt'**, tým väčšia je hodnota **'erytrocyty'**.
# Závislosť atribútu **'erytrocyty'** od atribútu **'alt'** má **logaritmickú** krivku.

# %% [markdown]
# #### Leukocyty a Erytrocyty

# %% [markdown]
# Podľa tabuľky korelácii vieme, že aj atribút **'erytrocyty'** a atribút **'leukocyty'** majú nejakú súvislosť. Tieto dva atribúty majú koreláciu **0.33**.

# %%
sns.scatterplot(data=dataset, x='erytrocyty', y='leukocyty',s=6)
sns.histplot(data=dataset, x='erytrocyty', y='leukocyty')
sns.kdeplot(data=dataset, x='erytrocyty', y='leukocyty')
#sns.jointplot(data=dataset, x='erytrocyty', y='leukocyty')
# Out:
# <AxesSubplot:xlabel='erytrocyty', ylabel='leukocyty'>

# %% [markdown]
# Z grafu vieme vyčítať, že najväčší počet erytrocytov a leukocytov sa nachádza medzi hodnotou 6 a 8.

# %% [markdown]
# #### Erytrocyty a Hematokrit

# %% [markdown]
# Atribút **'erytrocyty'** a atribút **'hematokrit'** majú **negatívnú** koreláciu. Ich korelácia je **-0.47**.

# %%
sns.scatterplot(data=dataset, x='erytrocyty', y='hematokrit',s=6)
sns.histplot(data=dataset, x='erytrocyty', y='hematokrit')
sns.kdeplot(data=dataset, x='erytrocyty', y='hematokrit')
# Out:
# <AxesSubplot:xlabel='erytrocyty', ylabel='hematokrit'>

# %% [markdown]
# Tuná vidíme, že erytrocyty sú najčastejšie medzi hodnotami 6 a 8, pokiaľ je hematokrit medzi hodnotou 4 a 6.

# %% [markdown]
# #### Trombocyty a Alt

# %% [markdown]
# Korelácia medzi atribútom **'trombocyty'** a atribútom **'alt'** je **-0.25**.

# %%
sns.scatterplot(data=dataset, x='trombocyty', y='alt')
# Out:
# <AxesSubplot:xlabel='trombocyty', ylabel='alt'>

# %% [markdown]
# Z grafu môžeme vidieť, že ak je alt medzi hodnotou 20 a 40, tak sa trombocyty nachádzajú medzi hodnotami 4 a 6.

# %% [markdown]
# #### Trombocyty a Erytrocyty

# %% [markdown]
# Medzi atribútom **'trombocyty'** a atribútom **'erytrocyty'** je taktiež negatívna korelácia **-0.34**.

# %%
sns.scatterplot(data=dataset, x='trombocyty', y='erytrocyty',s=6)
sns.histplot(data=dataset, x='trombocyty', y='erytrocyty')
sns.kdeplot(data=dataset, x='trombocyty', y='erytrocyty')
# Out:
# <AxesSubplot:xlabel='trombocyty', ylabel='erytrocyty'>

# %% [markdown]
# Vidíme, že počet trombocytov a erytrocytov sa najčastejšie nachádza medzi hodontami 6 a 8.

# %% [markdown]
# ### Závislosti medzi predikovanou premennou a ostatnými premennými

# %% [markdown]
# #### Indicator a Trombocyty

# %% [markdown]
# Korelácia medzi atribútom **'indicator'** a atribútom **'trombocyty'** je **najvyššia pozitívna** z uvedených dvojíc. Táto korelácia dosahuje hodnotu **0.63**.

# %%
sns.violinplot(data=dataset, x='indicator', y='trombocyty')
#dataset.head()
# Out:
# <AxesSubplot:xlabel='indicator', ylabel='trombocyty'>

# %% [markdown]
# Pomocou grafu typu violinplot môžeme vidieť, že čím vyššie sú trombocyty, tým vyšší je indicator.
# Z tejto korelácie nám môže vyplývať, že vyššie trombocyty znamenajú horší stav pacienta s leukémiou.

# %% [markdown]
# #### Indicator a Erytrocyty

# %% [markdown]
# Korelácia medzi atribútmu **'indicator'** a **'erytrocyty'** je **najvyššia negatívna** korelácia medzi predikovanou premennou a inou premennou.
# Táto korelácia dosahuje hodnotu **-0.32**.

# %%
sns.violinplot(data=dataset, x='indicator', y='erytrocyty')
# Out:
# <AxesSubplot:xlabel='indicator', ylabel='erytrocyty'>

# %% [markdown]
# Podľa grafu violinplot vidíme, že pacienti s horším stavom majú menšie množstvo erytrocytov ako pacienti v lepšom stave.

# %% [markdown]
# ## 3. Formulácia a štatistické overenie hypotéz o dátach
#
# Hypotéza 1:
#
# H0 - Pacientov stav nesúvisi s fajčením
#
# H1 - Pacienti, ktorí fajčia majú horší stav leukémie
#
# Hypotéza 2:
#
# H0 - Počet trombocytov u pacienta nesúvisi s jeho stavom
#
# H1 - Pacienti, ktorí majú vyšší počet trombocytov majú horší stav leukémie

# %% [markdown]
# ### Hypotéza 1:
#
# V stĺpci "smoker" musíme zmeniť hodnoty tak, aby boli jednotné. Pre toto sme si spravili slovník replacement_dict.
# Hodnoty "Y" a "yes" vymeníme za hodnotu 1, zatiaľčo hodnoty "N" a "no" vymeníme za hodnotu 0.

# %%
smoker_series = dataset['smoker']
replacement_dict = {
    "Y": 1,
    "yes": 1,
    "N": 0,
    "no": 0
}
dataset["smoker"].replace(replacement_dict, inplace=True)
smokers = dataset.loc[(dataset["smoker"] == 1), "indicator"]
non_smokers = dataset.loc[(dataset["smoker"] == 0), "indicator"]

# %% [markdown]
# Kolačový graf pre podiel fajčiarov a nefajčiarov:

# %%
plt.pie([len(smokers), len(non_smokers)], labels = ["smokers","non smokers"], colors = ['c','b'], startangle = 90, shadow = True, explode = (0.1, 0.1), autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1873cd5cf10>,
#   <matplotlib.patches.Wedge at 0x1873cd40970>],
#  [Text(-1.137903295731835, 0.3810198020610325, 'smokers'),
#   Text(1.137903295731835, -0.3810198020610326, 'non smokers')],
#  [Text(-0.6637769225102369, 0.22226155120226893, '40%'),
#   Text(0.6637769225102369, -0.222261551202269, '60%')])

# %%
print("Počet fajčiarov:",smokers.count())
print("Počet nefajčiarov:",non_smokers.count())
# Out:
# Počet fajčiarov: 3987
# Počet nefajčiarov: 6052

# %% [markdown]
# Vidíme, že počet nefajčiarov je väčší ako počet fajčiarov. Aby sme mali čo najpresnejšiu štatistiku, potrebujeme zobrať (približne) rovnakú vzorku pre obe distribúcie. Preto z datasetu nefajčiari zoberieme len takú veľku vzorku ako je počet fajčiarov. Toto zabezpečíme pomocou funkcie sample() z knižnice pandas. Funkcia sample nám vyberie náhodnú vzorku z datasetu o špecifikovanej veľkosti. Táto vzorka je náhodná a tým pádom bude p hodnota pri rôznych testoch stále trochu iná. To nám ale v konečnom prípade nijak nebude vadiť, pretože výsledok testu bude stále rovnaký.

# %%
non_smokers = non_smokers.sample(smokers.count())
non_smokers.count()
# Out:
# 3987

# %% [markdown]
# Teraz máme rovnaký počet subjektov v oboch vzorkách.

# %% [markdown]
# #### Zistenie normálovej distribúcie:

# %%
shapiro_test = sc.stats.shapiro(smokers)

if sc.stats.shapiro(smokers).pvalue > 0.05 and sc.stats.shapiro(non_smokers).pvalue > 0.05:
    print("Je to normálova distribúcia")
else:
    print("Nie je to normálova distribúcia")
# Out:
# Nie je to normálova distribúcia

# %% [markdown]
# Shapirov test nám ukázal, že distribúcia nie je normálova.
#
# Teraz je potrebné zistiť, či distribúcia je párovaná alebo nepárovaná. To znamená, či sa 2 alebo viaceré skupiny skladajú z rovnakých testovacích subjektov. Keďže sme si pacientov rozdelili na tých, čo fajčia a tých čo nefajčia, znamená to, že testovacia distribúcia je nepárovaná.
#
# Máme nenormálovu, nepárovanú distribúciu 2 skupín a teda spravíme Man-Whitneyho U test.

# %% [markdown]
# #### Mann-Whitney U test:

# %%
whitney = sc.stats.mannwhitneyu(smokers,non_smokers)
print("Pvalue hodnota po vykonaní testu Mann-Whitney U: ",whitney.pvalue)

if whitney.pvalue > 0.05:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Pvalue hodnota po vykonaní testu Mann-Whitney U:  0.8885614553217681
# Same distribution (fail to reject H0)

# %% [markdown]
# Z Mann-Whitneyho U testu sme dostali p hodnotu väčšiu ako 0.05 -> nevieme potvrdiť hypotézu (fail to reject H0).

# %% [markdown]
# ### Hypotéza 2:

# %% [markdown]
# Pre druhú hypotézu si rozdelíme dataset na pacientov s indikátorom 0 a pacientov s indikátorom 1. Pri týchto pacientoch nás bude zaujímať ich hodnota atribútu trombocyty.

# %%
trombocyty_zero = dataset.loc[(dataset["indicator"] == 0), "trombocyty"]
trombocyty_zero = trombocyty_zero.dropna()
trombocyty_one = dataset.loc[(dataset["indicator"] == 1), "trombocyty"]
trombocyty_one = trombocyty_one.dropna()

# %% [markdown]
# Kolačový graf pre rozdelenie pacientov s indikátorom 0 a pacientov s indikátorom 1:

# %%
plt.pie([len(trombocyty_zero), len(trombocyty_one)], labels = ["patients with indicator 0","patients with indicator 1"], colors = ['c','b'], startangle = 90, shadow = True, explode = (0.1, 0.1), autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1873d328eb0>,
#   <matplotlib.patches.Wedge at 0x1873d310d00>],
#  [Text(-1.0823620862308192, 0.5181624400610961, 'patients with indicator 0'),
#   Text(1.0823620862308192, -0.5181624400610962, 'patients with indicator 1')],
#  [Text(-0.6313778836346444, 0.30226142336897266, '36%'),
#   Text(0.6313778836346444, -0.30226142336897277, '64%')])

# %%
print("Počet pacientov s indikátorom 0:",trombocyty_zero.count())
print("Počet pacientov s indikátorom 1:",trombocyty_one.count())
# Out:
# Počet pacientov s indikátorom 0: 3582
# Počet pacientov s indikátorom 1: 6427

# %% [markdown]
# Aj tuná musíme zmenšiť vzorku pre distribúciu trombocyty_one.

# %%
trombocyty_one = trombocyty_one.sample(trombocyty_zero.count())
trombocyty_one.count()
# Out:
# 3582

# %% [markdown]
# Teraz máme v oboch vzorkách rovnaký počet subjektov.

# %% [markdown]
# #### Zistenie normálovej distribúcie:

# %%
if sc.stats.shapiro(trombocyty_zero).pvalue > 0.05 and sc.stats.shapiro(trombocyty_one).pvalue > 0.05:
    print("Je to normálova distribúcia")
else:
    print("Nie je to normálova distribúcia")
# Out:
# Nie je to normálova distribúcia

# %% [markdown]
# Zo shapirovho testu sme zistili, že daná distribúcia nie je normálova.
#
# Pacientov sme si rozdelili na 2 skupiny, tých s indikátorom 0 a tých s indikátorom 1. To znamená, že táto distribúcia je nepárovaná.
#
# Máme nenormálovu, nepárovanú distribúciu 2 skupín a teda spravíme Man-Whitneyho U test.

# %% [markdown]
# #### Mann-Whitney U test:

# %%
if sc.stats.mannwhitneyu(trombocyty_zero, trombocyty_one).pvalue > 0.05:
    print('Same distribution (fail to reject H0)')
else:
    print('Different distribution (reject H0)')
# Out:
# Different distribution (reject H0)

# %% [markdown]
# Po vykonaní Man-Whitneyho U testu môžeme zamietnuť hypotézu H0. Z toho nám vyplýva, že hypotéza H1 je správna.

# %% [markdown]
# ## 4. Identifikácia problémov v dátach s navrhnutým riešením
#
# V datasete, s ktorým sme doteraz pracovali sú nejaké chyby (chýbajúce hodnoty, vychýlené hodnoty, nejednotné formáty, atď.). Zistíme počet chybných riadkov, v ktorých chýba aspoň jedna hodnota.

# %%
dataset.isna().sum()
# Out:
# name             0
# hematokrit      31
# smoker           0
# leukocyty       30
# relationship     0
# ssn              0
# alt             30
# weight           0
# erytrocyty      30
# alp             31
# ast             30
# er-cv           30
# etytr           31
# hemoglobin      30
# trombocyty      30
# indicator        0
# hbver           30
# dtype: int64

# %% [markdown]
# Riadky, ktoré obsahujú nekompletné údaje môžeme odstrániť.

# %% [markdown]
# Následne si zistíme unikátne záznamy v jednotlivých stĺpcoch. Pre číselné záznamy nepotrebujeme zisťovať unikátne záznamy.

# %%
for column in dataset.columns:
    if dataset[column].dtypes == 'object':
        print("{}:".format(column), "\n", dataset[column].unique(),"\n")
# Out:
# name:
#  ['Courtney Sparks' 'David Cook' 'Diane Dunn' ... 'Andrea Torres'
#  'April Butler' 'Wendy Cole']
#
# relationship:
#  ['married' 'divoced' 'separated' 'nop' 'single' 'widowed']
#
# ssn:
#  ['211-15-5030' '134-25-6459' '410-38-6674' ... '115-96-1449' '476-98-5349'
#  '055-26-1339']

# %% [markdown]
# Ako môžeme vidieť, pri menách a SSN nám taktiež nezáleží na unikátnych záznamoch. Kde nám ale záleží na unikátnych záznamoch je stĺpec relationship. Vidíme, že obsahuje 6 unikátnych záznamov. Tieto záznamy majú nejaké gramatické chyby, preto ich upravíme (napr. "divoced" -> "divorced", "nop" -> "not specified").

# %% [markdown]
# Teraz sa pozrime na druhý dataset.

# %%
dataprofiles = pd.read_csv("042/profiles.csv", delimiter="\t")
dataprofiles
# Out:
#       Unnamed: 0 blood_group                     company  \
# 0              0          A-                    Yu Group
# 1              1          O-      Chase, Brown and Price
# 2              2          O+  Martinez, Medina and Myers
# 3              3          O-              Odonnell-Weber
# 4              4          O-               Velazquez Ltd
# ...          ...         ...                         ...
# 3055        3055          O-   Ramirez, Chambers and Lee
# 3056        3056          O-    Bennett, Porter and Diaz
# 3057        3057          O-                  Ward Group
# 3058        3058          O+              Jenkins-Turner
# 3059        3059          A-                 Cochran Ltd
#
#                              job          ssn sex             birthdate  \
# 0               Engineer, energy  383-82-1198   M  08/10/1946, 00:00:00
# 1            Designer, furniture  828-02-1024   M            1933/01/31
# 2      Medical technical officer  604-55-3198   F            1989-11-29
# 3                   Neurosurgeon  235-52-1947   M  10/07/1975, 00:00:00
# 4                      Homeopath  160-55-3346   F  06/16/1934, 00:00:00
# ...                          ...          ...  ..                   ...
# 3055       Multimedia specialist  129-93-9411   M            2010/08/23
# 3056  Nurse, learning disability  073-31-8151   F  03/15/2013, 00:00:00
# 3057                Town planner  496-75-4226   F  07/28/1916, 00:00:00
# 3058         Administrator, arts  895-70-8728   F            1928-02-29
# 3059    Horticultural consultant  045-64-6276   F            1913-04-26
#
#           race                 name  \
# 0        White           John Beard
# 1        Black         Dustin Oneal
# 2     Hawaiian         Rachel Brown
# 3        Black       Robert Johnson
# 4        White  Stephanie Rodriguez
# ...        ...                  ...
# 3055     Black           Adam Owens
# 3056     Black      Pamela Tapia MD
# 3057     Black     Crystal Anderson
# 3058     Asian         Emily Walker
# 3059     Asian        Sophia Spence
#
#                                                 address
# 0         2896 Juan Manor\nNorth Douglasmouth, LA 50163
# 1        225 Moore Glen Suite 019\nAmandastad, WA 64166
# 2              51910 Timothy Lane\nHorneburgh, DE 96504
# 3     5654 Kimberly Points Suite 971\nSouth Robinshi...
# 4              25985 Kyle Terrace\nPamelaland, CA 64245
# ...                                                 ...
# 3055          798 Brown Centers\nWest Kristin, AL 16008
# 3056  328 Sanchez River Suite 664\nSolishaven, CA 16716
# 3057                   Unit 0796 Box 7005\nDPO AA 92880
# 3058  574 James Crossroad Suite 057\nDeanfort, WY 09541
# 3059  6211 Powers Walk Suite 408\nNew Amandashire, M...
#
# [3060 rows x 10 columns]

# %% [markdown]
# Skúsme zistiť, či sa v ňom nachádzajú nejaké duplikátne záznamy. Každý človek má pridelené unikátne SSN (social security number) a preto hľadáme duplikátne SSN.

# %%
data_test = dataprofiles.drop_duplicates(subset="ssn")
print("Duplikátne riadky: ",dataprofiles["ssn"].count() - data_test["ssn"].count())
# Out:
# Duplikátne riadky:  0

# %% [markdown]
# Zistili sme, že v danom datasete sa nenachádzajú žiadne duplikátne záznamy.

# %% [markdown]
# V datasete sa nachádzajú rôzne formáty dátumu narodenia. To by sme mali upraviť na jednotný formát.

# %%
dataprofiles['birthdate']
# Out:
# 0       08/10/1946, 00:00:00
# 1                 1933/01/31
# 2                 1989-11-29
# 3       10/07/1975, 00:00:00
# 4       06/16/1934, 00:00:00
#                 ...
# 3055              2010/08/23
# 3056    03/15/2013, 00:00:00
# 3057    07/28/1916, 00:00:00
# 3058              1928-02-29
# 3059              1913-04-26
# Name: birthdate, Length: 3060, dtype: object

# %% [markdown]
# Takisto sa tam nachádzajú nejednotné údaje pre rasu. Môžeme si všimnúť, že pre jednu rasu sa v datasete nachádzajú viaceré hodnoty (napr. black, Black, blsck). To môžeme upraviť na jednu hodnotu.

# %%
dataprofiles["race"].unique()
# Out:
# array(['White', 'Black', 'Hawaiian', 'Indian', 'Asian', 'white', 'black',
#        'blsck'], dtype=object)

# %% [markdown]
# Teraz zistíme vychýlené hodnoty.
#
# Počet vychýlených hodnôt pre jednotlivé stĺpce vypíšeme. Najviac vychýlených hodnôt sme našli v stĺcoch **Alp** a **Alt**.
# Tieto vychýlené hodnoty neskôr vymeníme pomocou funkcie Winsorize.

# %%
def check_for_outliers(data, column_name: str):
    # calculate summary statistics
    data_mean, data_std = np.mean(data), np.std(data)

    # define outliers
    cut_off = data_std * 3
    lower, upper = data_mean - cut_off, data_mean + cut_off

    # identify outliers
    length = len(column_name)
    column_name += " outliers"
    column_name += ' '*(10-length)
    outliers = [x for x in data if x < lower or x > upper]
    print(column_name.capitalize()+': %d' % len(outliers))

# %%
for column in dataset.describe().columns:
    check_for_outliers(dataset[column], column)
# Out:
# Hematokrit outliers: 14
# Smoker outliers    : 0
# Leukocyty outliers : 5
# Alt outliers       : 123
# Weight outliers    : 21
# Erytrocyty outliers: 3
# Alp outliers       : 150
# Ast outliers       : 29
# Er-cv outliers     : 27
# Etytr outliers     : 35
# Hemoglobin outliers: 31
# Trombocyty outliers: 21
# Indicator outliers : 0
# Hbver outliers     : 37

# %%
sns.histplot(dataset["weight"])
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %% [markdown]
# Z tohto grafu môžeme vidieť, že v datasete sa nachádzajú záznamy o váhe s negatívnou hodnotou. To je samozrejme hlúposť a musíme s tým niečo spraviť. Zistíme si koľko takých vychýlených hodnôt v datasete existuje.
#
# Vytvoríme si slovník weight_dict, kde sú minimálne a maximálne váhy pre mužov a ženy. Podľa tohto slovníku zistíme koľko vychýlených hodnôt máme v datasete pre mužov a pre ženy.

# %%
weight_dict = {
    "Male_min": 43,
    "Male_max": 100,
    "Female_min": 41,
    "Female_max": 90
}
# zdroj pre tieto hodnoty: https://www.healthifyme.com/blog/height-weight-chart-ideal-weight-for-men-and-women/

# %%
counter_m = 0
counter_n = 0
for i in range(len(dataset["weight"])):
    index_in_profiles = pd.Index(dataprofiles["ssn"]).get_loc(dataset["ssn"][i])
    get_sex = dataprofiles["sex"][index_in_profiles]
    if get_sex == 'M':
        if not (weight_dict["Male_min"] < dataset["weight"][i] < weight_dict["Male_max"] ):
            counter_m += 1
    else:
        if not (weight_dict["Female_min"] < dataset["weight"][i] < weight_dict["Female_max"] ):
            counter_n += 1

print("Počet vychýlených hodnôt pre mužov:", counter_m)
print("Počet vychýlených hodnôt pre žien:", counter_n)
# Out:
# Počet vychýlených hodnôt pre mužov: 2103
# Počet vychýlených hodnôt pre žien: 2443

# %% [markdown]
# Neskôr možeme tieto hodnoty vymeniť za iné hodnoty (náhodne vygenerované hodnoty z rozsahu Male_mix po Male_max resp. Female_min po Female_max).

# %% [markdown]
# V časti **"Formulácia a štatistické overenie hypotéz o dátach"** sme našli nevhodnú štruktúru dát. V stĺpci "smoker" sme vymenili typ údajov na číselné hodnoty, kde 1 reprezentuje, že daný pacient fajčí a 0, že daný pacient nefajčí.
#
# smoker_series = dataset['smoker']
#
# replacement_dict = {
#     "Y": 1,
#     "yes": 1,
#     "N": 0,
#     "no": 0
# }
#
# dataset["smoker"].replace(replacement_dict, inplace=True)

# %% [markdown]
# Uloženie dát do csv súborov.

# %%
dataset.to_csv("faza1/labor.csv")
dataprofiles.to_csv("faza1/profiles.csv")
